# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv("Student Depression Dataset.csv")
df
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df.describe()
# Out:
#                   id           Age  Academic Pressure  Work Pressure  \
# count   27901.000000  27901.000000       27901.000000   27901.000000
# mean    70442.149421     25.822300           3.141214       0.000430
# std     40641.175216      4.905687           1.381465       0.043992
# min         2.000000     18.000000           0.000000       0.000000
# 25%     35039.000000     21.000000           2.000000       0.000000
# 50%     70684.000000     25.000000           3.000000       0.000000
# 75%    105818.000000     30.000000           4.000000       0.000000
# max    140699.000000     59.000000           5.000000       5.000000
#
#                CGPA  Study Satisfaction  Job Satisfaction  Work/Study Hours  \
# count  27901.000000        27901.000000      27901.000000      27901.000000
# mean       7.656104            2.943837          0.000681          7.156984
# std        1.470707            1.361148          0.044394          3.707642
# ...

# %%
df.shape
# Out:
# (27901, 18)

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         3
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.drop_duplicates()
# Out:
#            id  Gender   Age           City Profession  Academic Pressure  \
# 0           2    Male  33.0  Visakhapatnam    Student                5.0
# 1           8  Female  24.0      Bangalore    Student                2.0
# 2          26    Male  31.0       Srinagar    Student                3.0
# 3          30  Female  28.0       Varanasi    Student                3.0
# 4          32  Female  25.0         Jaipur    Student                4.0
# ...       ...     ...   ...            ...        ...                ...
# 27896  140685  Female  27.0          Surat    Student                5.0
# 27897  140686    Male  27.0       Ludhiana    Student                2.0
# 27898  140689    Male  31.0      Faridabad    Student                3.0
# 27899  140690  Female  18.0       Ludhiana    Student                5.0
# 27900  140699    Male  27.0          Patna    Student                4.0
#
#        Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# ...

# %%
df=df.dropna()

# %%
df.isnull().sum()
# Out:
# id                                       0
# Gender                                   0
# Age                                      0
# City                                     0
# Profession                               0
# Academic Pressure                        0
# Work Pressure                            0
# CGPA                                     0
# Study Satisfaction                       0
# Job Satisfaction                         0
# Sleep Duration                           0
# Dietary Habits                           0
# Degree                                   0
# Have you ever had suicidal thoughts ?    0
# Work/Study Hours                         0
# Financial Stress                         0
# Family History of Mental Illness         0
# Depression                               0
# dtype: int64

# %%
df.head(5)
# Out:
#    id  Gender   Age           City Profession  Academic Pressure  \
# 0   2    Male  33.0  Visakhapatnam    Student                5.0
# 1   8  Female  24.0      Bangalore    Student                2.0
# 2  26    Male  31.0       Srinagar    Student                3.0
# 3  30  Female  28.0       Varanasi    Student                3.0
# 4  32  Female  25.0         Jaipur    Student                4.0
#
#    Work Pressure  CGPA  Study Satisfaction  Job Satisfaction  \
# 0            0.0  8.97                 2.0               0.0
# 1            0.0  5.90                 5.0               0.0
# 2            0.0  7.03                 5.0               0.0
# 3            0.0  5.59                 2.0               0.0
# 4            0.0  8.13                 3.0               0.0
#
#       Sleep Duration Dietary Habits   Degree  \
# 0          5-6 hours        Healthy  B.Pharm
# 1          5-6 hours       Moderate      BSc
# 2  Less than 5 hours        Healthy       BA
# ...

# %%
df['Profession'].unique()
# Out:
# array(['Student', 'Civil Engineer', 'Architect', 'UX/UI Designer',
#        'Digital Marketer', 'Content Writer', 'Educational Consultant',
#        'Teacher', 'Manager', 'Chef', 'Doctor', 'Lawyer', 'Entrepreneur',
#        'Pharmacist'], dtype=object)

# %%
df['Dietary Habits'].unique()
# Out:
# array(['Healthy', 'Moderate', 'Unhealthy', 'Others'], dtype=object)

# %%
df['Profession'].unique()
# Out:
# array(['Student', 'Civil Engineer', 'Architect', 'UX/UI Designer',
#        'Digital Marketer', 'Content Writer', 'Educational Consultant',
#        'Teacher', 'Manager', 'Chef', 'Doctor', 'Lawyer', 'Entrepreneur',
#        'Pharmacist'], dtype=object)

# %%
df['Sleep Duration'].unique()
# Out:
# array(['5-6 hours', 'Less than 5 hours', '7-8 hours', 'More than 8 hours',
#        'Others'], dtype=object)

# %%
df['City'].unique()
# Out:
# array(['Visakhapatnam', 'Bangalore', 'Srinagar', 'Varanasi', 'Jaipur',
#        'Pune', 'Thane', 'Chennai', 'Nagpur', 'Nashik', 'Vadodara',
#        'Kalyan', 'Rajkot', 'Ahmedabad', 'Kolkata', 'Mumbai', 'Lucknow',
#        'Indore', 'Surat', 'Ludhiana', 'Bhopal', 'Meerut', 'Agra',
#        'Ghaziabad', 'Hyderabad', 'Vasai-Virar', 'Kanpur', 'Patna',
#        'Faridabad', 'Delhi', 'Saanvi', 'M.Tech', 'Bhavna', 'Less Delhi',
#        'City', '3.0', 'Less than 5 Kalyan', 'Mira', 'Harsha', 'Vaanya',
#        'Gaurav', 'Harsh', 'Reyansh', 'Kibara', 'Rashi', 'ME', 'M.Com',
#        'Nalyan', 'Mihir', 'Nalini', 'Nandini', 'Khaziabad'], dtype=object)

# %%
df.drop("id",axis='columns',inplace=True)
# Out:
# C:\Users\Ankita\AppData\Local\Temp\ipykernel_29364\3718791198.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop("id",axis='columns',inplace=True)

# %%
Categorical_columns=["Gender","Have you ever had suicidal thoughts ?","Family History of Mental Illness"]

# %%
df=pd.get_dummies(df,columns=Categorical_columns)

# %%
df.drop(columns=["Gender_Female","Have you ever had suicidal thoughts ?_No","Family History of Mental Illness_No"],axis="columns",inplace=True)

# %%
columns=["City","Profession","Sleep Duration","Dietary Habits","Degree"]

# %%
from sklearn.preprocessing import LabelEncoder

# %%
label_encoder=LabelEncoder()
for column in df.columns:
    df[column]=label_encoder.fit_transform(df[column])

# %%
df
# Out:
#        Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0       15    51          11                  5              0   266
# 1        6     3          11                  2              0    62
# 2       13    44          11                  3              0   133
# 3       10    49          11                  3              0    34
# 4        7    16          11                  4              0   207
# ...    ...   ...         ...                ...            ...   ...
# 27896    9    45          11                  5              0    47
# 27897    9    25          11                  2              0   292
# 27898   13     9          11                  3              0   105
# 27899    0    25          11                  5              0   124
# 27900    9    38          11                  4              0   282
#
#        Study Satisfaction  Job Satisfaction  Sleep Duration  Dietary Habits  \
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=df[[col for col in df.columns if col!='Depression']+["Depression"]]
df.head()
# Out:
#    Age  City  Profession  Academic Pressure  Work Pressure  CGPA  \
# 0   15    51          11                  5              0   266
# 1    6     3          11                  2              0    62
# 2   13    44          11                  3              0   133
# 3   10    49          11                  3              0    34
# 4    7    16          11                  4              0   207
#
#    Study Satisfaction  Job Satisfaction  Sleep Duration  Dietary Habits  \
# 0                   2                 0               0               0
# 1                   5                 0               0               1
# 2                   5                 0               2               0
# 3                   2                 0               1               1
# 4                   3                 0               0               1
#
#    Degree  Work/Study Hours  Financial Stress  Gender_Male  \
# 0       3                 3                 0            1
# ...

# %%
x=df.iloc[:, :-1]
y=df.iloc[:, -1]

# %%
correlation=pd.concat([x,y],axis=1)
sns.heatmap(correlation.corr(),annot=True,cmap="coolwarm")
plt.title("correlation Heatmap")
plt.show()

# %%
sns.pairplot(df,vars=["Age","Academic Pressure","Work Pressure","CGPA","Job Satisfaction"],hue="Depression")
plt.plot()
# Out:
# []

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=98,test_size=0.25,shuffle=True)

# %% [markdown]
# ## Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr=LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
# Out:
# D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score
acc=accuracy_score(y_test,y_pred)
print("The accuracy score is:",acc)
# Out:
# The accuracy score is: 0.837562724014337

# %% [markdown]
# ## Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
dt=DecisionTreeClassifier(random_state=1)
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=1)

# %%
y_pred=dt.predict(x_test)
y_pred
# Out:
# array([0, 1, 0, ..., 1, 1, 1], dtype=int64)

# %%
acc=accuracy_score(y_test,y_pred)
print("The accuracy score is:",acc)
# Out:
# The accuracy score is: 0.7618637992831542

# %% [markdown]
# ## Removing Outliers

# %%
sns.boxplot(x='Depression', y='Age', data=df)
plt.title('Age vs Depression')
plt.show()

# %%
sns.boxplot(x='Depression', y='Job Satisfaction', data=df)
plt.title('Job Satisfaction vs Depression')
plt.show()

# %%
sns.boxplot(x='Depression', y='Work Pressure', data=df)
plt.title('Study Satisfaction vs Depression')
plt.show()

# %%
Q1=df['Age'].quantile(0.25)
Q3=df['Age'].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df1=df[(df['Age']>=lower_bound)& (df['Age']<=upper_bound)]

# %%
Q1=df['Job Satisfaction'].quantile(0.25)
Q3=df['Job Satisfaction'].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df1=df[(df['Job Satisfaction']>=lower_bound)& (df['Job Satisfaction']<=upper_bound)]

# %%
Q1=df['Work Pressure'].quantile(0.25)
Q3=df['Work Pressure'].quantile(0.75)
IQR=Q3-Q1

lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

df1=df[(df['Work Pressure']>=lower_bound)& (df['Work Pressure']<=upper_bound)]

# %%
sns.pairplot(df1,vars=["Age","Academic Pressure","Work Pressure","CGPA","Job Satisfaction"],hue="Depression")
plt.plot()
# Out:
# []

# %% [markdown]
# ## Logistic Regression

# %%
x=df1.iloc[:, :-1]
y=df1.iloc[:, -1]

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=98,test_size=0.25,shuffle=True)

# %%
lr=LogisticRegression(random_state=0)
lr.fit(x_train,y_train)
# Out:
# D:\anaconda\lib\site-packages\sklearn\linear_model\_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression(random_state=0)

# %%
y_pred=lr.predict(x_test)

# %%
acc=accuracy_score(y_test,y_pred)
print("Accuracy after outliers removal is:",acc)
# Out:
# Accuracy after outliers removal is: 0.8411241755090335
